# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q -P . https://archive.apache.org/dist/spark/spark-3.4.3/spark-3.4.3-bin-hadoop3.tgz
# !tar xf spark-3.4.3-bin-hadoop3.tgz
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.3-bin-hadoop3"
# !pip install -q findspark
# !pip install -q pyspark
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyspark (setup.py) ... done

# %%
import findspark

findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").appName('CERTUS Pyspark - Fernando Anco').getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://20af3eb254ee:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CERTUS Pyspark - Fernando Anco</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Probando la sesión de Spark
#tabla_1
data = [("Spark", "Python")] *10
df = spark.createDataFrame(data, ["Columna 1 Big_Data", "Columna 2 Big_Data"])
df.show()
# Out:
# +------------------+------------------+
# |Columna 1 Big_Data|Columna 2 Big_Data|
# +------------------+------------------+
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# |             Spark|            Python|
# +------------------+------------------+

# %%
#tabla_2
df = spark.createDataFrame([("Python", "Explora Python es un Lenguaje versatil") for _ in range(10)], ["Columna 1 Big Data", "Columna 2 Big Data"])
df.show()
# Out:
# +------------------+--------------------+
# |Columna 1 Big Data|  Columna 2 Big Data|
# +------------------+--------------------+
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# |            Python|Explora Python es...|
# +------------------+--------------------+
